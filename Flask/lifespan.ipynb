# %%
import json

# %%
with open('Resources/lifespan_world.json', 'r') as file:
    data = json.load(file)

data
# Out:
# {'lifespan': [{'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1960,
#    'Life expectancy at birth, total (years)': 32.44599914550781},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1961,
#    'Life expectancy at birth, total (years)': 32.96200180053711},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1962,
#    'Life expectancy at birth, total (years)': 33.47100067138672},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1963,
#    'Life expectancy at birth, total (years)': 33.97100067138672},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1964,
#    'Life expectancy at birth, total (years)': 34.4630012512207},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1965,
#    'Life expectancy at birth, total (years)': 34.948001861572266},
#   {'Entity': 'Afghanistan',
#    'Code': 'AFG',
#    'Year': 1966,
#    'Life expectancy at birth, total (years)': 35.43000030517578},
# ...
